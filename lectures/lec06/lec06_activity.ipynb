# %%
## imports
import pandas as pd
import numpy as np

# You might need to install lxml package for pd.read_html to work
# conda activate qss20
# conda install lxml

# %% [markdown]
# ## Scraping NFL Draft Data
# Steps:
# 1. Build the functions and test it out in Jupyter Notebook
# 2. Write the python script to loop through all players
# 3. Run the python script and save the logs from the terminal
#
# https://www.pro-football-reference.com/

# %%
players_df = pd.read_csv("./2024_drafted_players.csv")
players_df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0          Rnd       Pick         Tm               Player        Pos
# 1            1          1        CHI       Caleb Williams         QB
# 2            1          2        WAS       Jayden Daniels         QB
# 3            1          3        NWE           Drake Maye         QB
# 4            1          4        ARI  Marvin Harrison Jr.         WR
# ..         ...        ...        ...                  ...        ...
# 253          7        253        LAC    Cornelius Johnson         WR
# 254          7        254        LAR          KT Leveston         OL
# 255          7        255        GNB           Kalen King         CB
# 256          7        256        DEN        Nick Gargiulo         OL
# 257          7        257        NYJ           Jaylen Key        SAF
#
#     Unnamed: 5 Unnamed: 6 Misc Misc.1 Unnamed: 9  ... Rushing.2 Receiving  \
# ...

# %%
players_df = pd.read_csv("./2024_drafted_players.csv", skiprows=1)
players_df
# Out:
#      Rnd  Pick   Tm               Player  Pos  Age      To  AP1  PB  St  ...  \
# 0      1     1  CHI       Caleb Williams   QB   22  2025.0    0   0   1  ...
# 1      1     2  WAS       Jayden Daniels   QB   23  2025.0    0   1   1  ...
# 2      1     3  NWE           Drake Maye   QB   22  2025.0    0   2   1  ...
# 3      1     4  ARI  Marvin Harrison Jr.   WR   22  2025.0    0   0   1  ...
# 4      1     5  LAC              Joe Alt   OL   21  2025.0    0   1   1  ...
# ..   ...   ...  ...                  ...  ...  ...     ...  ...  ..  ..  ...
# 252    7   253  LAC    Cornelius Johnson   WR   23     NaN    0   0   0  ...
# 253    7   254  LAR          KT Leveston   OL   24  2025.0    0   0   0  ...
# 254    7   255  GNB           Kalen King   CB   21  2025.0    0   0   0  ...
# 255    7   256  DEN        Nick Gargiulo   OL   24     NaN    0   0   0  ...
# 256    7   257  NYJ           Jaylen Key  SAF   24     NaN    0   0   0  ...
#
# ...

# %%
players_df.iloc[:, -1].tolist()
# Out:
# ['WillCa03',
#  'DaniJa02',
#  'MayeDr00',
#  'HarrMa09',
#  'AltxJo01',
#  'NabeMa00',
#  'LathJC00',
#  'PeniMi00',
#  'OdunRo00',
#  'McCaJJ00',
#  'FashOl00',
#  'NixxBo00',
#  'BoweBr01',
#  'FuagTa00',
#  'LatuLa00',
#  'MurpBy01',
#  'TurnDa01',
#  'MimsAm00',
#  'VersJa00',
#  'FautTr00',
#  'RobiCh00',
#  'MitcQu00',
#  'ThomBr06',
#  'ArnoTe00',
#  'MorgJo03',
#  'BartGr00',
#  'RobiDa01',
#  'WortXa00',
#  'GuytTy00',
#  'WiggNa00',
#  'PearRi00',
#  'LegeXa00',
#  'ColeKe02',
#  'McCoLa00',
#  'OrhoRu00',
#  'NewtJe00',
#  'PolkJa00',
#  'SweaTV01',
#  'FiskBr00',
#  'DeJeCo00',
#  'McKiKo00',
#  'LassKa00',
#  'MeltMa00',
#  'PoweJa00',
#  'CoopEd00',
#  'BrooJo02',
#  'NubiTy00',
#  'SmitMa07',
#  'JenkKr01',
#  'SainMi00',
#  'FrazZa00',
#  'MitcAd00',
#  'SinnBe00',
#  'HallMi00',
#  'PaulPa01',
#  'KneeMa00',
#  'BrasCh01',
#  'BullJa00',
#  'FishBl00',
#  'BishCo00',
#  'RakeEn00',
#  'RoseRo01',
#  'SuamKi00',
#  'GreeRe00',
#  'CorlMa00',
#  'BensTr01',
# ...

# %%
def get_player_ids(player_list_path):
    df = pd.read_csv(player_list_path, skiprows=1)
    return df.iloc[:, -1].tolist()

# %%
player_id = "BoweBr01"

# The URL for Brock Bowers' stats
url = f"https://www.pro-football-reference.com/players/{player_id[0]}/{player_id}.htm"

# read_html returns a list of all tables found on the page
tables = pd.read_html(url)

# The 'rushing_and_receiving' table is typically the first one (index 0)
df = tables[0]

# Display the first few rows
print(df.head())

# Optional: Save to CSV
# df.to_csv('bowers_stats.csv', index=False)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                 Date               Team Unnamed: 2_level_1                Opp
# 0         2025-12-21                LVR                  @                HOU
# 1         2025-12-14                LVR                  @                PHI
# 2         2025-12-07                LVR                NaN                DEN
# 3         2025-11-30                LVR                  @                LAC
# 4         2025-11-23                LVR                NaN                CLE
#
#   Unnamed: 4_level_0 Receiving                   ... Rushing                 \
#               Result       Tgt Rec Yds   Y/R TD  ...     Att Yds TD Lng Y/A
# 0           L, 21-23         5   5  33   6.6  1  ...       0   0  0   0 NaN
# 1            L, 0-31         8   6  28   4.7  0  ...       0   0  0   0 NaN
# 2           L, 17-24         5   4  46  11.5  1  ...       0   0  0   0 NaN
# ...

# %%
tables[1]
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Season                Age               Team                 Lg
# 0               2024                 22                LVR                NFL
# 1               2025                 23                LVR                NFL
# 2              2 Yrs              2 Yrs              2 Yrs              2 Yrs
# 3        17 Game Avg        17 Game Avg        17 Game Avg        17 Game Avg
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Receiving       \
#                  Pos                  G                 GS       Tgt  Rec
# 0                 TE                 17                 16       153  112
# 1                 TE                 12                  8        86   64
# 2                NaN                 29                 24       239  176
# 3                NaN                 17                 14       140  103
#
# ...

# %%
df = tables[1]
df.to_csv(f"./data/player_stats/{player_id}.csv", index=False)

# %%
def get_player_stats(player_id):
    # The URL for the player's stats
    url = f"https://www.pro-football-reference.com/players/{player_id[0]}/{player_id}.htm"
    # read_html returns a list of all tables found on the page
    tables = pd.read_html(url)
    # The 'rushing_and_receiving' table is typically the first one (index 0)
    df = tables[1]
    return df

# %% [markdown]
# Complete the python script for `./code/collect_player_stats.py` to scrape the rushing and receiving stats for all players listed in `./data/2024_drafted_players.csv`
# - Save them as individual CSV files in the `./data/player_stats/` directory
# - Use a random sleep time between 0.05 to 2 seconds between requests to avoid overwhelming the server
# - Log progress to `./log/collect_player_stats.log` with `python -u ./code/collect_player_stats.py >> ./log/collect_player_stats.log`
